# %%
import requests

# %% [markdown]
# el dominio que se consulta es ponyweb.ml

# %%
status = requests.get("https://ponyweb.ml/v1/character/all")
status.status_code
# Out:
# 200

# %%
info = requests.get("https://ponyweb.ml/v1/character/all")
info.headers
# Out:
# {'Date': 'Wed, 22 Jun 2022 18:04:53 GMT', 'Server': 'Apache/2.4.38 (Debian)', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=63072000', 'Upgrade': 'h2', 'Connection': 'Upgrade, Keep-Alive', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Content-Length': '5670', 'Keep-Alive': 'timeout=5, max=100', 'Content-Type': 'application/json; charset=UTF-8'}

# %%
ponies = requests.get("https://ponyweb.ml/v1/character/Pony")
(ponies.json())
# Out:
# {'status': 200,
#  'data': [{'id': 93,
#    'name': 'Stygian',
#    'alias': 'Pony of Shadows',
#    'url': 'https://mlp.fandom.com/wiki/Stygian',
#    'sex': 'Male',
#    'residence': 'Hollow Shades',
#    'occupation': 'Scholar\nStrategist\nAuthor',
#    'kind': ['Unicorn', 'Umbrum'],
#    'image': ['https://vignette.wikia.nocookie.net/mlp/images/7/74/Stygian_ID_S7E26.png/revision/latest?cb=20171012213100',
#     'https://vignette.wikia.nocookie.net/mlp/images/e/ea/Nightmare_Knights_issue_3_Colt_Stygian.png/revision/latest?cb=20190906155534',
#     'https://vignette.wikia.nocookie.net/mlp/images/8/82/Pony_of_Shadows_ID_S7E26.png/revision/latest?cb=20171012213121',
#     'https://vignette.wikia.nocookie.net/mlp/images/6/6e/LoM_Annual_2018_Alternate_Stygian.png/revision/latest?cb=20180509215132']},
#   {'id': 176,
#    'name': 'The Pony Tones',
#    'alias': 'Ponytones',
#    'url': 'https://mlp.fandom.com/wiki/The_Pony_Tones',
#    'occupation': 'Singing ensemble',
# ...

# %%
song= requests.get("https://ponyweb.ml/v1/song/all")
song.json()
# Out:
# {'status': 200,
#  'data': [{'id': 1,
#    'name': 'Laughter Song',
#    'video': 'https://youtube.com/watch?v=xK-UWPb7MY4',
#    'length': '00:01:08',
#    'url': 'https://mlp.fandom.com/wiki/Laughter_Song',
#    'episode': 'Friendship is Magic, part 2',
#    'musicby': 'Daniel Ingram',
#    'lyricsby': 'Lauren Faust',
#    'keysignature': 'D major'},
#   {'id': 2,
#    'name': "Pinkie's Gala Fantasy Song",
#    'video': 'https://youtube.com/watch?v=Jjm4zw6X12s',
#    'length': '00:00:39',
#    'url': 'https://mlp.fandom.com/wiki/Pinkie%27s_Gala_Fantasy_Song',
#    'episode': 'The Ticket Master',
#    'musicby': 'Daniel Ingram\nSteffan Andrews (orchestration)',
#    'lyricsby': 'Lauren Faust\nAmy Keating Rogers',
#    'keysignature': 'G major'},
#   {'id': 3,
#    'name': 'The Ticket Song',
#    'video': 'https://youtube.com/watch?v=JTebDuVt9M8',
#    'length': '00:00:16',
#    'url': 'https://mlp.fandom.com/wiki/The_Ticket_Song',
#    'episode': 'The Ticket Master',
# ...

# %%
import requests

nuevo= requests.get("https://ponyweb.ml/v1/character/44")
print(nuevo.json()["data"])
# Out:
# [{'id': 44, 'name': 'Zephyr Breeze', 'url': 'https://mlp.fandom.com/wiki/Zephyr_Breeze', 'sex': 'Male', 'residence': 'Cloudsdale\nPonyville (briefly in S6E11)', 'occupation': 'Mane therapist\nSalonist at The Mane Event\nRoyal guard (briefly)', 'kind': ['Pegasus'], 'image': ['https://vignette.wikia.nocookie.net/mlp/images/1/14/Zephyr_Breeze_ID_S6E11.png/revision/latest?cb=20160605103015']}]

# %%
import requests

pony44= requests.get("https://ponyweb.ml/v1/character/44")
elementos= pony44.json()['data']
for i in elementos:
    q = i['name']

pony44_2 = str(pony44.json())

with open(q + '.txt', 'w') as f:
    f.write(pony44_2)
