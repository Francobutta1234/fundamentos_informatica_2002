# %%
# !pip3 install seaborn
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 22.1.1 is available.
# You should consider upgrading via the 'C:\Users\Franco\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import seaborn as sns
import pandas as pd
import scipy.stats as ss

personas = pd.read_csv(r"C:\Users\Franco\Downloads\personas_2011.csv", sep=";")
print(personas.head())
print(personas.describe()) #sirve para sacar calculos estadisticos
print(personas.info()) #sirve para sacar información
print(personas["edad"]) #para acceder solamente a la edad
print(personas["persona_id"].head(3))
print(personas.iloc[0,0])
print(personas.loc[0,"persona_id"])
print(personas["persona_id"].tolist())
print(personas["seniority_level"].count())
print(personas.groupby("seniority_level").count())
print(personas.groupby("seniority_level")[["persona_id"]].count())
list(personas)
personas[personas["sexo_id"] == "2"].count()
# Out:
#    persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 0           1  2011        2    36                         -1
# 1           5  2011        1    48                          1
# 2           7  2011        2    30                          5
# 3          10  2011        2    51                          5
# 4          11  2011        1    39                          2
#
#    disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 0                                    -1                          -1
# 1                                   255                         255
# 2                                   111                         111
# 3                                   248                         248
# 4                                   223                         203
#
#    disciplina_experticia_id  tipo_personal_id  producciones_ult_anio  ...  \
# 0                        64                 4                      0  ...
# ...

# %%
personas[(personas["sexo_id"] == 1) & (personas["edad"] < 40)]
# Out:
#        persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 4              11  2011        1    39                          2
# 10             21  2011        1    34                          1
# 27             46  2011        1    34                          1
# 28             48  2011        1    38                          1
# 33             55  2011        1    38                          1
# ...           ...   ...      ...   ...                        ...
# 68539      185408  2011        1    38                          3
# 68542      185455  2011        1    -1                         -1
# 68543      185513  2011        1    24                         -1
# 68544      185515  2011        1    21                          7
# 68551      185608  2011        1    27                          5
#
#        disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 4                                       223                         203
# ...

# %%
personas.describe()
# Out:
#           persona_id     anio       sexo_id          edad  \
# count   68552.000000  68552.0  68552.000000  68552.000000
# mean    52537.987280   2011.0      1.423430     38.475172
# std     40279.541919      0.0      0.494106     12.483655
# min         1.000000   2011.0      1.000000     -1.000000
# 25%     22112.500000   2011.0      1.000000     29.000000
# 50%     44284.500000   2011.0      1.000000     37.000000
# 75%     73350.250000   2011.0      2.000000     48.000000
# max    185608.000000   2011.0      2.000000     88.000000
#
#        maximo_grado_academico_id  disciplina_maximo_grado_academico_id  \
# count               68552.000000                          68552.000000
# mean                    3.306847                            152.966726
# std                     2.258145                            112.218458
# min                    -1.000000                             -1.000000
# 25%                     1.000000                             26.000000
# ...

# %%
personas["seniority_level"] = personas["seniority_level"].astype("string")
personas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68552 entries, 0 to 68551
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   persona_id                            68552 non-null  int64
#  1   anio                                  68552 non-null  int64
#  2   sexo_id                               68552 non-null  int64
#  3   edad                                  68552 non-null  int64
#  4   maximo_grado_academico_id             68552 non-null  int64
#  5   disciplina_maximo_grado_academico_id  68552 non-null  int64
#  6   disciplina_titulo_grado_id            68552 non-null  int64
#  7   disciplina_experticia_id              68552 non-null  int64
#  8   tipo_personal_id                      68552 non-null  int64
#  9   producciones_ult_anio                 68552 non-null  int64
#  10  producciones_ult_2_anios              68552 non-null  int64
# ...

# %%
personas.rename(columns={"seniority_level":"Hola"})
# Out:
#        persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 0               1  2011        2    36                         -1
# 1               5  2011        1    48                          1
# 2               7  2011        2    30                          5
# 3              10  2011        2    51                          5
# 4              11  2011        1    39                          2
# ...           ...   ...      ...   ...                        ...
# 68547      185558  2011        2    -1                         -1
# 68548      185574  2011        2    55                         -1
# 68549      185583  2011        2    18                          7
# 68550      185590  2011        2    -1                          8
# 68551      185608  2011        1    27                          5
#
#        disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 0                                        -1                          -1
# ...

# %%
personas[personas["seniority_level"].str.contains("A")].head()
# Out:
#        persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 9              19  2011        2    52                          1
# 12             23  2011        2    58                          1
# 15             26  2011        1    60                          1
# 16             27  2011        1    51                          5
# 19             32  2011        1    47                          1
# ...           ...   ...      ...   ...                        ...
# 65935      150413  2011        1    57                          2
# 65948      151054  2011        1    49                          3
# 65983      152466  2011        1    39                          5
# 67557      176778  2011        1    51                          2
# 68438      182436  2011        1    57                          2
#
#        disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 9                                       255                         255
# ...

# %%
personas.loc[19, "seniority_level"]
# Out:
# 'A  '

# %%
personas.loc[19]
# Out:
# persona_id                                 32
# anio                                     2011
# sexo_id                                     1
# edad                                       47
# maximo_grado_academico_id                   1
# disciplina_maximo_grado_academico_id      106
# disciplina_titulo_grado_id                 38
# disciplina_experticia_id                   38
# tipo_personal_id                            3
# producciones_ult_anio                      11
# producciones_ult_2_anios                   19
# producciones_ult_3_anios                   21
# producciones_ult_4_anios                   23
# institucion_trabajo_id                    877
# seniority_level                           A
# categoria_conicet_id                      3.0
# categoria_incentivos                      2.0
# max_dedicacion_horaria_docente_id         3.0
# institucion_cargo_docente_id            356.0
# clase_cargo_docente_id                   69.0
# ...

# %%
cat_a = personas[personas["seniority_level"].str.contains("A")]
cat_b = personas[personas["seniority_level"].str.contains("B")]
pd.concat([cat_a, cat_b])
# Out:
#        persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 9              19  2011        2    52                          1
# 12             23  2011        2    58                          1
# 15             26  2011        1    60                          1
# 16             27  2011        1    51                          5
# 19             32  2011        1    47                          1
# ...           ...   ...      ...   ...                        ...
# 68080      179905  2011        1    48                          1
# 68123      180191  2011        1    47                          1
# 68151      180414  2011        1    55                          2
# 68374      181894  2011        1    49                          2
# 68401      182042  2011        1    49                          2
#
#        disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 9                                       255                         255
# ...

# %%
personas.head()
# Out:
#    persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 0           1  2011        2    36                         -1
# 1           5  2011        1    48                          1
# 2           7  2011        2    30                          5
# 3          10  2011        2    51                          5
# 4          11  2011        1    39                          2
#
#    disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 0                                    -1                          -1
# 1                                   255                         255
# 2                                   111                         111
# 3                                   248                         248
# 4                                   223                         203
#
#    disciplina_experticia_id  tipo_personal_id  producciones_ult_anio  ...  \
# 0                        64                 4                      0  ...
# ...

# %%
personas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68552 entries, 0 to 68551
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   persona_id                            68552 non-null  int64
#  1   anio                                  68552 non-null  int64
#  2   sexo_id                               68552 non-null  int64
#  3   edad                                  68552 non-null  int64
#  4   maximo_grado_academico_id             68552 non-null  int64
#  5   disciplina_maximo_grado_academico_id  68552 non-null  int64
#  6   disciplina_titulo_grado_id            68552 non-null  int64
#  7   disciplina_experticia_id              68552 non-null  int64
#  8   tipo_personal_id                      68552 non-null  int64
#  9   producciones_ult_anio                 68552 non-null  int64
#  10  producciones_ult_2_anios              68552 non-null  int64
# ...

# %%
personas.isnull().sum()
# Out:
# persona_id                                  0
# anio                                        0
# sexo_id                                     0
# edad                                        0
# maximo_grado_academico_id                   0
# disciplina_maximo_grado_academico_id        0
# disciplina_titulo_grado_id                  0
# disciplina_experticia_id                    0
# tipo_personal_id                            0
# producciones_ult_anio                       0
# producciones_ult_2_anios                    0
# producciones_ult_3_anios                    0
# producciones_ult_4_anios                    0
# institucion_trabajo_id                      0
# seniority_level                             0
# categoria_conicet_id                    19912
# categoria_incentivos                    19912
# max_dedicacion_horaria_docente_id       19912
# institucion_cargo_docente_id            19912
# clase_cargo_docente_id                  19912
# ...

# %%
import seaborn as sns

sns.heatmap(personas.isnull(), cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
personas['maximo_grado_academico_id'].value_counts()
# Out:
#  5    26932
#  1    15075
#  2     7764
#  3     7204
#  7     5271
# -1     5055
#  6     1017
#  8      234
# Name: maximo_grado_academico_id, dtype: int64

# %%
personas.dropna(thresh=2, inplace=True)
personas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48640 entries, 0 to 68545
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   persona_id                            48640 non-null  int64
#  1   anio                                  48640 non-null  int64
#  2   sexo_id                               48640 non-null  int64
#  3   edad                                  48640 non-null  int64
#  4   maximo_grado_academico_id             48640 non-null  int64
#  5   disciplina_maximo_grado_academico_id  48640 non-null  int64
#  6   disciplina_titulo_grado_id            48640 non-null  int64
#  7   disciplina_experticia_id              48640 non-null  int64
#  8   tipo_personal_id                      48640 non-null  int64
#  9   producciones_ult_anio                 48640 non-null  int64
#  10  producciones_ult_2_anios              48640 non-null  int64
# ...

# %%
personas.fillna(personas['categoria_incentivos'].mean(), inplace=True)

# %%
personas["categoria_incentivos"].dtype
# Out:
# dtype('float64')

# %%
personas.drop_duplicates(inplace=True)
